# %%
import pandas as pd

# %%
df_spbu = pd.read_csv('spbu_comments.csv')
df_spbu[['text','id','from_id']]
# Out:
#                                                     text      id    from_id
# 0      заочка*\n\nэт первое\n\nа второе, лучше узнать...  381651  472121925
# 1                                                     Да  381629  154032610
# 2      Нет. В таких случаях ориентируйся на правила п...  381646   10702362
# 3                                                      +  381617  664875401
# 4      Выполняю работы по математике,  обращайтесь 😉 ...  381618   31951761
# ...                                                  ...     ...        ...
# 12887         Тесты донные, лучше взять перевод за баллы  332453  227576670
# 12888                                    Ес. Сохраняется  332336  280652844
# 12889                                                NaN  332349          0
# 12890                                               Дааа  332351   75061935
# 12891                                                 Да  332387   54756152
#
# [12892 rows x 3 columns]

# %%
df_msu = pd.read_csv('msu_comments.csv')
df_msu[['text','id','from_id']]
# Out:
#                                                     text      id    from_id
# 0      Почему не поверим? В ВШЭ есть факультет дизайн...  445828  360217145
# 1                            Пффф, а в МГУ Азат Мифтахов  445829  245028077
# 2              Ну естественно ВШЭ, МГУшник не попался бы  445831  408514951
# 3                                      Тэгал, небось😁😁😁😁  445832  537302811
# 4      Мгушникам российский мент дороже брата из вышк...  445842  221156367
# ...                                                  ...     ...        ...
# 48080                                                NaN  276065   36543494
# 48081                        как красиво) ты мой герой😇😇  276031   10432035
# 48082                              Лайк за кавер "Мцыри"  276033    3086601
# 48083                        Лермонтов😍😍\nРеспект автору  276037   15110019
# 48084                                Ооочень красиво!!))  276327  129411382
#
# [48085 rows x 3 columns]
